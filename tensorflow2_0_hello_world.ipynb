# %% [markdown]
# <a href="https://colab.research.google.com/github/wuxianshikong/tensorflow2.0-/blob/master/tensorflow2_0_hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Coures 1 Tensorflow2.0 -预测 y=x*x+1

# %% [markdown]
# - ## 首先import相关库

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# - ## 定义神经网络框架

# %%
model=tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# 这里units代表层数
# input_shape代表输入的维度

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %% [markdown]
# 这里设置了优化算法和损失函数
# 其中优化算法设置为随机梯度下降法：sgd
# 损失函数设置为方差均值：mean_squared_error

# %% [markdown]
# - ## 提供数据

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# - ## 开始训练
# 训练步骤为500次

# %%
model.fit(xs,ys,epochs=500)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/500
# 6/6 [==============================] - 0s 79ms/sample - loss: 41.4429
# Epoch 2/500
# 6/6 [==============================] - 0s 1ms/sample - loss: 32.9660
# Epoch 3/500
# 6/6 [==============================] - 0s 413us/sample - loss: 26.2893
# Epoch 4/500
# 6/6 [==============================] - 0s 918us/sample - loss: 21.0292
# Epoch 5/500
# 6/6 [==============================] - 0s 926us/sample - loss: 16.8837
# Epoch 6/500
# 6/6 [==============================] - 0s 908us/sample - loss: 13.6153
# Epoch 7/500
# 6/6 [==============================] - 0s 722us/sample - loss: 11.0370
# Epoch 8/500
# 6/6 [==============================] - 0s 744us/sample - loss: 9.0019
# Epoch 9/500
# ...

# %% [markdown]
# - ## 打印预测值

# %%
print(model.predict([10.0]))
# Out:
# [[18.977495]]
